# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import PIL
#real note
A = cv2.imread('2000 real.jpg',)
B = cv2.imread('500 real.jpg',)
C = cv2.imread('200 real.jpg',)

plt.subplot(1,3,1)
plt.title('Real Note 2000')
plt.imshow(A)
plt.subplot(1,3,2)
plt.title('Real Note 500')
plt.imshow(B)
plt.subplot(1,3,3)
plt.title('Real Note 200')
plt.imshow(C)
# Out:
#   Cell In[6], line 2
#     import matplotlib from(C:\users\akash\appdata\local\programs\python\python36\lib\site-packages\matplotlib)
#                       ^
# SyntaxError: invalid syntax

# %%
X = cv2.imread('2000 fake.jpg')
Y = cv2.imread('500 fake.jpg')
Z = cv2.imread('200 fake.jpg')
plt.subplot(1,3,1)
plt.title('Fake Note 2000')
plt.imshow(X)
plt.subplot(1,3,2)
plt.title('Fake Note 500')
plt.imshow(Y)
plt.subplot(1,3,3)
plt.title('Fake Note 200')
plt.imshow(Z)

# %%
#scaning real notes
a = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)
plt.imshow(a)

# %%
#scaning real notes
x = cv2.cvtColor(X, cv2.COLOR_BGR2GRAY)
plt.imshow(x)

# %%
b = cv2.cvtColor(B, cv2.COLOR_BGR2GRAY)
plt.imshow(b)

# %%
y = cv2.cvtColor(Y, cv2.COLOR_BGR2GRAY)
plt.imshow(y)

# %%
c = cv2.cvtColor(C, cv2.COLOR_BGR2GRAY)
plt.imshow(c)

# %%
z = cv2.cvtColor(Z, cv2.COLOR_BGR2GRAY)
plt.imshow(z)

# %%
print(x.shape)
x2_str =x[300:600,800 :1000]
plt.imshow(x2_str)
# Out:
# (519, 1291)

# %%
print(x.shape)
x2_str =x[50:300,1150 :1300]
plt.imshow(x2_str)
# Out:
# (519, 1291)

# %%
print(y.shape)
y2_str =y[60:110,180 :240]
plt.imshow(y2_str)
# Out:
# (150, 337)

# %%
print(y.shape)
y2_str =y[30:100,300 :350]
plt.imshow(y2_str)
# Out:
# (150, 337)

# %%
print(c.shape)
c2_str =c[0:588,0: 1302]
plt.imshow(c2_str)
# Out:
# (588, 1302)

# %%
realnoteA = cv2.cvtColor(A,   cv2.COLOR_BGR2HLS_FULL )
fakenoteX = cv2.cvtColor(X, cv2.COLOR_BGR2HLS_FULL)
plt.subplot(1,2,1)
plt.title('Real Note')
plt.imshow(realnoteA)
plt.subplot(1,2,2)
plt.title('fakenoteX')
plt.imshow(fakenoteX)

# %%
realnoteB = cv2.cvtColor(B, cv2.COLOR_BGR2LUV)
fakenoteY = cv2.cvtColor(Y, cv2.COLOR_BGR2LUV)

plt.subplot(1,2,1)
plt.title('Real Note')
plt.imshow(realnoteB)
plt.subplot(1,2,2)
plt.title('fakenote')
plt.imshow(fakenoteY)

# %%
realnoteC = cv2.cvtColor(C, cv2.COLOR_BGR2HLS)
fakenoteZ = cv2.cvtColor(Z, cv2.COLOR_BGR2HLS)
plt.subplot(1,2,1)
plt.title('Real Note')
plt.imshow(realnoteC)
plt.subplot(1,2,2)
plt.title('fakenote')
plt.imshow(fakenoteZ)

# %%
import PIL
img1 = PIL.Image.open('output/2000 outputreal.png')
img2 = PIL.Image.open('output/2000 outputfake.png')
img3 = PIL.Image.open('output/500 outputreal.png')
img4 = PIL.Image.open('output/500 outputfake.png')
img5 = PIL.Image.open('output/200 outputreal.png')
img6 = PIL.Image.open('output/200 outputfake.png')

# %%
if img1==img2:
    print('The Given Currency is Real')
    plt.imshow(img1)

else:
    print('The currency is fake')
    plt.imshow(img2)
# Out:
# The currency is fake

# %%
if img3==img4:
    print('The Given Currency is Real')
    plt.imshow(img3)

else:
    print('The currency is fake')
    plt.imshow(img4)
# Out:
# The currency is fake

# %%
if img5==img6:
    print('The Given Currency is Real')
    plt.imshow(img5)

else:
    print('The currency is fake')
    plt.imshow(img6)
# Out:
# The Given Currency is Real

# %%
#importing streamlit library

import streamlit as st

from PIL import Image



#opening the image

image = Image.open('2000 real.jpg')



#displaying the image on streamlit app

st.image(image, caption='Enter any caption here')
# Out:
# 2023-03-21 14:01:37.581
# ...
#   command:
#
#     streamlit run C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
